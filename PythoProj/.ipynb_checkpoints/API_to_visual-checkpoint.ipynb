# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'c31cff1f-de71-42a6-8cf1-c76a841cecd8',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2025-02-06T18:45:56.566Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 8279, 'name': 'jkm6vyuho0s', 'symbol': '5n0q1qn273s', 'slug': 'lqby79p03k', 'cmc_rank': 573, 'num_market_pairs': 9659, 'circulating_supply': 8553, 'total_supply': 8378, 'max_supply': 1817, 'infinite_supply': None, 'last_updated': '2025-02-06T18:45:56.565Z', 'date_added': '2025-02-06T18:45:56.565Z', 'tags': ['ynqmgu508rj', 'gysf4t2xios', 'rx81f47nfzs', 'wrb7i0v3dak', 'unrz7oirpwa', 'co93ll3bvj', 'j56retqekq', 'zk73qjo6d8q', '23pvrxquav3', 'n98bo86xbsp'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7836782201384513, 'volume_24h': 5685, 'volume_change_24h': 0.9838059706631754, 'percent_change_1h': 0.44072915357780285, 'percent_change_24h': 0.3488276983945673, 'percent_change_7d': 0.6958004960334454, 'market_cap': 0.6231831856342038, 'market_cap_dominance': 7535, 'fully_diluted_market_cap': 0.75403864607382, 'last_updated': '2025-02-06T18:45:56.565Z'}}}, {'id': 1158, 'name': 'mqpe4gv1ep', 'symbol': '53cliym1328', 'slug': 'qkvrqvi2lt', 'cmc_rank': 7216, 'num_market_pairs': 9542, 'circulating_supply': 3247, 'total_supply': 2076, 'max_supply': 5087, 'infinite_supply': None, 'last_updated': '2025-02-06T18:45:56.565Z', 'date_added': '2025-02-06T18:45:56.565Z', 'tags': ['4lzqr6mafsx', 'vctl4lpuq', 'cajrf2kf1ar', 'vkz312y2efd', 'vv0b2xw4u2j', 'gwhebz9m27l', '594peoetf2', 'c0hial0luye', 'qeqfh4ocmg8', 'ajlasdn4us'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6105939659612183, 'volume_24h': 4353, 'volume_change_24h': 0.6082566271461967, 'percent_change_1h': 0.8224760472506718, 'percent_change_24h': 0.8010676522565008, 'percent_change_7d': 0.3459284636515192, 'market_cap': 0.22633548659601388, 'market_cap_dominance': 8165, 'fully_diluted_market_cap': 0.931101325271374, 'last_updated': '2025-02-06T18:45:56.565Z'}}}, {'id': 4630, 'name': 'y18x3egd42j', 'symbol': 'lk287qm2lne', 'slug': 'jljcogf59a', 'cmc_rank': 2174, 'num_market_pairs': 9060, 'circulating_supply': 6487, 'total_supply': 3826, 'max_supply': 9744, 'infinite_supply': None, 'last_updated': '2025-02-06T18:45:56.565Z', 'date_added': '2025-02-06T18:45:56.565Z', 'tags': ['fetezehsvt', '3lvuke74lsk', 'k2cl9wbk89h', 'khdk1s5y8d', 'hxbprkjxo2r', 'fbknjw9vfjp', 'm1ep9c852k', 's2xbqqdm72', '9dliw9v0y9a', '8qo23t6350o'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6271468233518127, 'volume_24h': 3443, 'volume_change_24h': 0.4061022546955917, 'percent_change_1h': 0.3052422338940177, 'percent_change_24h': 0.6028340698708963, 'percent_change_7d': 0.5306400450342836, 'market_cap': 0.8526037669787503, 'market_cap_dominance': 6746, 'fully_diluted_market_cap': 0.31688405941568076, 'last_updated': '2025-02-06T18:45:56.565Z'}}}, {'id': 5856, 'name': 'ykfm7hszf8m', 'symbol': 'g0mfohulh', 'slug': '2n85polc5y3', 'cmc_rank': 9987, 'num_market_pairs': 6749, 'circulating_supply': 6514, 'total_supply': 9012, 'max_supply': 3642, 'infinite_supply': None, 'last_updated': '2025-02-06T18:45:56.565Z', 'date_added': '2025-02-06T18:45:56.565Z', 'tags': ['1dh095txekz', '3ozwgtrfzpv', 'tnyem1l6rcd', 'gy5602ak6gc', 'rwxq89z2rnk', 'v29mhbym5mj', 'epuxx7u1f6l', '3aqwaxgkhu', 'q6wff3c2y', 'umfurcp0vir'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6796779401992483, 'volume_24h': 6087, 'volume_change_24h': 0.45427456609860384, 'percent_change_1h': 0.15453645963617002, 'percent_change_24h': 0.560074193704688, 'percent_change_7d': 0.3522331653022206, 'market_cap': 0.0742569893047671, 'market_cap_dominance': 4943, 'fully_diluted_market_cap': 0.43400168538300377, 'last_updated': '2025-02-06T18:45:56.565Z'}}}, {'id': 1415, 'name': '9slmeh5hgg9', 'symbol': 'ems ...

# %%
data
# Out:
# {'status': {'timestamp': '2025-02-06T18:45:56.566Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 1,
#   'credit_count': 1,
#   'notice': None},
#  'data': [{'id': 8279,
#    'name': 'jkm6vyuho0s',
#    'symbol': '5n0q1qn273s',
#    'slug': 'lqby79p03k',
#    'cmc_rank': 573,
#    'num_market_pairs': 9659,
#    'circulating_supply': 8553,
#    'total_supply': 8378,
#    'max_supply': 1817,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['ynqmgu508rj',
#     'gysf4t2xios',
#     'rx81f47nfzs',
#     'wrb7i0v3dak',
#     'unrz7oirpwa',
#     'co93ll3bvj',
#     'j56retqekq',
#     'zk73qjo6d8q',
#     '23pvrxquav3',
#     'n98bo86xbsp'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.7836782201384513,
#      'volume_24h': 5685,
#      'volume_change_24h': 0.9838059706631754,
#      'percent_change_1h': 0.44072915357780285,
#      'percent_change_24h': 0.3488276983945673,
#      'percent_change_7d': 0.6958004960334454,
#      'market_cap': 0.6231831856342038,
#      'market_cap_dominance': 7535,
#      'fully_diluted_market_cap': 0.75403864607382,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 1158,
#    'name': 'mqpe4gv1ep',
#    'symbol': '53cliym1328',
#    'slug': 'qkvrqvi2lt',
#    'cmc_rank': 7216,
#    'num_market_pairs': 9542,
#    'circulating_supply': 3247,
#    'total_supply': 2076,
#    'max_supply': 5087,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['4lzqr6mafsx',
#     'vctl4lpuq',
#     'cajrf2kf1ar',
#     'vkz312y2efd',
#     'vv0b2xw4u2j',
#     'gwhebz9m27l',
#     '594peoetf2',
#     'c0hial0luye',
#     'qeqfh4ocmg8',
#     'ajlasdn4us'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.6105939659612183,
#      'volume_24h': 4353,
#      'volume_change_24h': 0.6082566271461967,
#      'percent_change_1h': 0.8224760472506718,
#      'percent_change_24h': 0.8010676522565008,
#      'percent_change_7d': 0.3459284636515192,
#      'market_cap': 0.22633548659601388,
#      'market_cap_dominance': 8165,
#      'fully_diluted_market_cap': 0.931101325271374,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 4630,
#    'name': 'y18x3egd42j',
#    'symbol': 'lk287qm2lne',
#    'slug': 'jljcogf59a',
#    'cmc_rank': 2174,
#    'num_market_pairs': 9060,
#    'circulating_supply': 6487,
#    'total_supply': 3826,
#    'max_supply': 9744,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['fetezehsvt',
#     '3lvuke74lsk',
#     'k2cl9wbk89h',
#     'khdk1s5y8d',
#     'hxbprkjxo2r',
#     'fbknjw9vfjp',
#     'm1ep9c852k',
#     's2xbqqdm72',
#     '9dliw9v0y9a',
#     '8qo23t6350o'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.6271468233518127,
#      'volume_24h': 3443,
#      'volume_change_24h': 0.4061022546955917,
#      'percent_change_1h': 0.3052422338940177,
#      'percent_change_24h': 0.6028340698708963,
#      'percent_change_7d': 0.5306400450342836,
#      'market_cap': 0.8526037669787503,
#      'market_cap_dominance': 6746,
#      'fully_diluted_market_cap': 0.31688405941568076,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 5856,
#    'name': 'ykfm7hszf8m',
#    'symbol': 'g0mfohulh',
#    'slug': '2n85polc5y3',
#    'cmc_rank': 9987,
#    'num_market_pairs': 6749,
#    'circulating_supply': 6514,
#    'total_supply': 9012,
#    'max_supply': 3642,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['1dh095txekz',
#     '3ozwgtrfzpv',
#     'tnyem1l6rcd',
#     'gy5602ak6gc',
#     'rwxq89z2rnk',
#     'v29mhbym5mj',
#     'epuxx7u1f6l',
#     '3aqwaxgkhu',
#     'q6wff3c2y',
#     'umfurcp0vir'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.6796779401992483,
#      'volume_24h': 6087,
#      'volume_change_24h': 0.45427456609860384,
#      'percent_change_1h': 0.15453645963617002,
#      'percent_change_24h': 0.560074193704688,
#      'percent_change_7d': 0.3522331653022206,
#      'market_cap': 0.0742569893047671,
#      'market_cap_dominance': 4943,
#      'fully_diluted_market_cap': 0.43400168538300377,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 1415,
#    'name': '9slmeh5hgg9',
#    'symbol': 'emsemojr2cj',
#    'slug': 'fitc36r5mih',
#    'cmc_rank': 9487,
#    'num_market_pairs': 9680,
#    'circulating_supply': 4485,
#    'total_supply': 6660,
#    'max_supply': 7796,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['oyvvwd95hp',
#     'u2f6c1ah0cj',
#     'nzzj2qd7ht',
#     'sbey1tdqdn',
#     'mv6i7u7fydh',
#     'csyju3jwgh6',
#     '46d8z47de9u',
#     'fmcpn1j99yq',
#     '00pz56v92h8g',
#     'mzypm9wg3xq'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.17652923548531585,
#      'volume_24h': 5647,
#      'volume_change_24h': 0.6794698314320156,
#      'percent_change_1h': 0.6555692677740816,
#      'percent_change_24h': 0.6554581736832108,
#      'percent_change_7d': 0.9273215446074343,
#      'market_cap': 0.06581322590123295,
#      'market_cap_dominance': 9625,
#      'fully_diluted_market_cap': 0.3558116842357941,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 202,
#    'name': '81yladhg7xv',
#    'symbol': 'kdxjcd5lbkn',
#    'slug': 'ibamy0mggq',
#    'cmc_rank': 8130,
#    'num_market_pairs': 7930,
#    'circulating_supply': 5972,
#    'total_supply': 8159,
#    'max_supply': 2165,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['5p8tz37dahe',
#     'vzfdo5v41nh',
#     '4xm90epb8k6',
#     'zzvrtrpd5qh',
#     'hawxqxl0oan',
#     'pmdob3tg5dq',
#     '100rm08ajni',
#     'ykxiek9r61j',
#     'e6zynpxjl8r',
#     '4cv8t6nvpqo'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.718554473480798,
#      'volume_24h': 8032,
#      'volume_change_24h': 0.7127167937091472,
#      'percent_change_1h': 0.8856949328528545,
#      'percent_change_24h': 0.6467437675904155,
#      'percent_change_7d': 0.7102457224365433,
#      'market_cap': 0.14953913820940823,
#      'market_cap_dominance': 2792,
#      'fully_diluted_market_cap': 0.0237784866037849,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 8763,
#    'name': 'rl51d01w5ng',
#    'symbol': 'nb9a2gfd7cq',
#    'slug': 'kxtpvnzodcn',
#    'cmc_rank': 453,
#    'num_market_pairs': 2450,
#    'circulating_supply': 766,
#    'total_supply': 2667,
#    'max_supply': 1222,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['h4rldeid8rr',
#     'przy1n8p93g',
#     'htcnf3b8iuh',
#     '2hw9kmbzgwj',
#     'bh4sxrqffmb',
#     'sz1sd6zjea',
#     '3y24ydqrtko',
#     'c0wuwn3kvs7',
#     'c9ljir3hk59',
#     'fi3eo16hocs'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.39649216669118026,
#      'volume_24h': 2422,
#      'volume_change_24h': 0.7513467799196587,
#      'percent_change_1h': 0.1463711090084412,
#      'percent_change_24h': 0.13873991679582476,
#      'percent_change_7d': 0.47691255664191834,
#      'market_cap': 0.9952715222474702,
#      'market_cap_dominance': 8737,
#      'fully_diluted_market_cap': 0.9936227645925353,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 7004,
#    'name': 'yk1n41dkack',
#    'symbol': '0mpnngpu00j',
#    'slug': 'ew11uiyh0dl',
#    'cmc_rank': 2638,
#    'num_market_pairs': 8174,
#    'circulating_supply': 7661,
#    'total_supply': 7223,
#    'max_supply': 155,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['qbli4olvai',
#     '0kgipg1unj',
#     'ohd4lrdgp0p',
#     '6j7qiurtnnt',
#     'alqwki5fau9',
#     'veq9rjul1ie',
#     'yx7js7tlvoa',
#     'cddyivbuiok',
#     'b9gb2890pbc',
#     'wf1hvgkylv'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.46818289220890663,
#      'volume_24h': 2292,
#      'volume_change_24h': 0.6048580220198814,
#      'percent_change_1h': 0.4605158369973259,
#      'percent_change_24h': 0.6712688528561233,
#      'percent_change_7d': 0.3507601655858188,
#      'market_cap': 0.22781882074378523,
#      'market_cap_dominance': 2017,
#      'fully_diluted_market_cap': 0.12633993178370084,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 7699,
#    'name': '2zctb79vcoj',
#    'symbol': 'uwp2gw09rwl',
#    'slug': '4ma6n9v56im',
#    'cmc_rank': 8614,
#    'num_market_pairs': 2612,
#    'circulating_supply': 7664,
#    'total_supply': 5742,
#    'max_supply': 8639,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['dqgn7eyd32',
#     'iqx6sptfj1j',
#     'hekb6vn0ho7',
#     '9jhtueo2jf5',
#     '1mjc0763qsp',
#     'k2x2v6ixxn',
#     'd7g0c92myi',
#     'w8kbgzzlzgi',
#     's9gxr42s4x',
#     'cq7cnvmqxga'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.7234250508683959,
#      'volume_24h': 2992,
#      'volume_change_24h': 0.5264750064268011,
#      'percent_change_1h': 0.11907384738192017,
#      'percent_change_24h': 0.12268966800971337,
#      'percent_change_7d': 0.8197287101260538,
#      'market_cap': 0.37519713432566415,
#      'market_cap_dominance': 2721,
#      'fully_diluted_market_cap': 0.680916612957783,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}},
#   {'id': 2222,
#    'name': 'h731y0gt5un',
#    'symbol': 'o4lo1ir5eyo',
#    'slug': 'mwrmvjo05i',
#    'cmc_rank': 3917,
#    'num_market_pairs': 9882,
#    'circulating_supply': 5672,
#    'total_supply': 5660,
#    'max_supply': 2641,
#    'infinite_supply': None,
#    'last_updated': '2025-02-06T18:45:56.565Z',
#    'date_added': '2025-02-06T18:45:56.565Z',
#    'tags': ['8bf2zpocfz9',
#     '2pt0nemnypf',
#     '2cj0sva6nk5',
#     '54m738xc8d',
#     '6mqksiuivgu',
#     '4xmn2retd9e',
#     'ygbv7wu9ppa',
#     'vg2cdne5a8',
#     'cr3ydqiaygp',
#     '2v0maoob5ya'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.19167059658514263,
#      'volume_24h': 5818,
#      'volume_change_24h': 0.7113653514020326,
#      'percent_change_1h': 0.21933342275691903,
#      'percent_change_24h': 0.26589748736963204,
#      'percent_change_7d': 0.16549972743434438,
#      'market_cap': 0.09660130318116678,
#      'market_cap_dominance': 2065,
#      'fully_diluted_market_cap': 0.6187134618021568,
#      'last_updated': '2025-02-06T18:45:56.565Z'}}}]}

# %%
import pandas as pd
data = pd.json_normalize(data['data'])

# %%
data
# Out:
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  4361  psi66qdh6d8   6ywic1a7uy   ez5ka5wtd04      1191               264
# 1  3642   mdjtj962at   93aoir04p5  0pht8jjf82a9      7300              8437
# 2  3835  6yjsw8804oi  sja9qcx2tpa   qh48gdyyex9       255              7966
# 3  7589  nuxfz2mue1o   oaw80iybym    uqsrewy96w      3192              8927
# 4  8709   qjjnxve7c6  dr42x9j5xcl   9ampv43spsh      4759                 8
# 5  4003  vxf5ouvx9ah   eoxoy1slh6   n30wrq8gn3r      6392              9425
# 6   519  5oi8vzn6dbj  uzhaivchffr   idfw51zbt2t      3764              3655
# 7  5228  erygio9q3id  th3nhn3e789   hztiw58pwwd      8378              7542
# 8  9665  icfk0bljvcn  3tdzidx4mpk    qn4g7fkg04       519              3111
# 9  2990   tvzapbsv4s  g7d2i2piwqa   aojyp5rv81l      3960              5787
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                9873          6875        8487            None  ...
# 1                4317          9428        6679            None  ...
# 2                 754          4617        2057            None  ...
# 3                6373          5369        3199            None  ...
# 4                 314          7087        5877            None  ...
# 5                7689          5712        1725            None  ...
# 6                8194          6704        4803            None  ...
# 7                4328          9294        1382            None  ...
# 8                8064          5547        7159            None  ...
# 9                7717          7423        6890            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.759018                 6916                    0.384744
# 1        0.057656                 9021                    0.956290
# 2        0.344510                 8178                    0.391640
# 3        0.571155                 7671                    0.961241
# 4        0.957986                  754                    0.557385
# 5        0.359250                 8322                    0.976121
# 6        0.809983                  553                    0.793514
# 7        0.748138                 2370                    0.091325
# 8        0.596840                 6946                    0.894502
# 9        0.639762                 9713                    0.022071
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.210248                     0.385792
# 1                    0.447332                     0.991501
# 2                    0.014071                     0.780117
# 3                    0.792661                     0.553761
# 4                    0.915127                     0.520763
# 5                    0.416699                     0.112974
# 6                    0.722184                     0.315398
# 7                    0.822795                     0.053086
# 8                    0.869497                     0.707222
# 9                    0.429942                     0.046421
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.407494              0.406133
# 1                    0.938987              0.563640
# 2                    0.323300              0.677588
# 3                    0.655545              0.402750
# 4                    0.303740              0.112218
# 5                    0.903240              0.350519
# 6                    0.129635              0.066191
# 7                    0.259825              0.294045
# 8                    0.427821              0.297593
# 9                    0.745401              0.948032
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            5830                            0.356832
# 1                            7064                            0.865273
# 2                            5370                            0.785666
# 3                             253                            0.637877
# 4                            2192                            0.616133
# 5                            5394                            0.267840
# 6                             112                            0.779355
# 7                            8828                            0.262503
# 8                            9054                            0.862160
# 9                            9739                            0.777137
#
#      quote.USD.last_updated
# 0  2025-02-06T15:37:11.266Z
# 1  2025-02-06T15:37:11.266Z
# 2  2025-02-06T15:37:11.266Z
# 3  2025-02-06T15:37:11.266Z
# 4  2025-02-06T15:37:11.266Z
# 5  2025-02-06T15:37:11.266Z
# 6  2025-02-06T15:37:11.266Z
# 7  2025-02-06T15:37:11.266Z
# 8  2025-02-06T15:37:11.266Z
# 9  2025-02-06T15:37:11.266Z
#
# [10 rows x 26 columns]
